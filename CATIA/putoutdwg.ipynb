# %%
import numpy as np
x=np.arange(3,48,1)

# %%
of= open('putputdwg.txt','a')
for i in x:
    of.write("""Set documents1 = CATIA.Documents

Dim drawingDocument%d As DrawingDocument
Set drawingDocument%d = documents1.Open("E:\\Users\\acer\Desktop\\fuselageout\\fuselage302\\cat\\tt%d.CATDrawing")

Set drawingDocument%d = CATIA.ActiveDocument

drawingDocument%d.ExportData "E:\\Users\\acer\Desktop\\fuselageout\\fuselage302\\dwg\\tt%d.dwg", "dwg"

Dim specsAndGeomWindow%d As SpecsAndGeomWindow
Set specsAndGeomWindow%d = CATIA.ActiveWindow

specsAndGeomWindow%d.Close

Set drawingDocument%d = CATIA.ActiveDocument

drawingDocument%d.Close
"""%(i,i,i,i,i,i,i,i,i,i,i))

# %%
of.close()
